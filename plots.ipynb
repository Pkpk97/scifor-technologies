# %%
import pandas as pd

# %%
import matplotlib.pyplot as plt
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 import matplotlib.pyplot as plt
#
# ModuleNotFoundError: No module named 'matplotlib'

# %%
pip install matplotlib
# Out:
# ...
#      ---------------------------------------- 0.0/160.4 kB ? eta -:--:--
#      ------------------------------------ - 153.6/160.4 kB 4.6 MB/s eta 0:00:01
#      -------------------------------------- 160.4/160.4 kB 3.2 MB/s eta 0:00:00
# ...
#    ---------------------------------------- 0.0/7.6 MB ? eta -:--:--
#    - -------------------------------------- 0.3/7.6 MB 8.6 MB/s eta 0:00:01
#    --- ------------------------------------ 0.7/7.6 MB 6.3 MB/s eta 0:00:02
#    ---- ----------------------------------- 1.0/7.6 MB 6.7 MB/s eta 0:00:02
#    ------ --------------------------------- 1.3/7.6 MB 6.6 MB/s eta 0:00:01
#    -------- ------------------------------- 1.6/7.6 MB 6.6 MB/s eta 0:00:01
#    --------- ------------------------------ 1.9/7.6 MB 6.3 MB/s eta 0:00:01
#    ----------- ---------------------------- 2.1/7.6 MB 6.5 MB/s eta 0:00:01
#    ------------ --------------------------- 2.5/7.6 MB 6.3 MB/s eta 0:00:01
# ...

# %%
import matplotlib.pyplot as plt

# %%
data=[['c1','m',34,123,'normal',350],
      ['c2','f',40,114,'overweight',450],
      ['c3','f',37,135,'obesity',169],
      ['c4','m',30,139,'overweight',189],
      ['c5','f',44,117,'underweight',183],
      ['c6','m',36,121,'normal',80],
      ['c7','m',32,133,'obesity',166],
      ['c8','f',26,140,'normal',120],
      ['c9','m',32,133,'normal',75],
      ['c10','m',36,133,'underweignt',40]]
df=pd.DataFrame(data,columns=['CID','gender','age','sales','bmi','income'])

# %%
df.hist()
# Out:
# array([[<Axes: title={'center': 'age'}>,
#         <Axes: title={'center': 'sales'}>],
#        [<Axes: title={'center': 'income'}>, <Axes: >]], dtype=object)

# %%
plt.show()

# %%
df.plot.bar()
# Out:
# <Axes: >

# %%
plt.scatter(df['income'],df['age'])
plt.show()

# %%
pip install seaborn
# Out:
# ...
#    ---------------------------------------- 0.0/294.8 kB ? eta -:--:--
#    ------------------- -------------------- 143.4/294.8 kB 4.3 MB/s eta 0:00:01
#    ---------------------------------------- 294.8/294.8 kB 4.6 MB/s eta 0:00:00
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 23.3.1 -> 23.3.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
pip install numpy
# Out:
# ...
# [notice] A new release of pip is available: 23.3.1 -> 23.3.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import seaborn as sns
import numpy as np
data=np.random.rand(10,12)
sns.heatmap(data,cmap='viridis')
plt.title('Heatmap Example')
plt.show()

# %%
df.plot.box()
plt.boxplot(df['income'])
plt.show()
